# %%
import scvelo as scv
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
import loompy
import numpy as np
import pandas as pd

# %%
top_dir = "/home/owenwhitley/projects/su2c_v2"
preproc_dir = os.path.join(top_dir, 'data/preprocessed/scRNA/velocyto_GBM_GSCs_split_by_sample_no_G800_L')
loom_file = os.path.join(preproc_dir, 'GSCs_GBM_combined_PCA_full.loom')

# %%
scv.logging.print_version()
scv.settings.verbosity = 3  # show errors(0), warnings(1), info(2), hints(3)
# scv.settings.presenter_view = True  # set max width size for presenter view
scv.set_figure_params('scvelo')  # for beautified visualization
# Out:
# Running scvelo 0.2.2 (python 3.8.5) on 2020-09-02 15:22.

# %%
loom_con = loompy.connect(loom_file)
plt.scatter(loom_con.ca['PC1'], loom_con.ca['PC2'])
loom_con.close()

# %%
adata = scv.read(loom_file, cache=False)
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata.var_names_make_unique()

# %%
scv.pl.proportions(adata)

# %%
scv.pp.filter_genes(adata, min_shared_counts=20)
scv.pp.normalize_per_cell(adata)
scv.pp.filter_genes_dispersion(adata, n_top_genes=2000)
scv.pp.log1p(adata)
# Out:
# Filtered out 45100 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Exctracted 2000 highly variable genes.

# %%
scv.tl.velocity(adata)
# Out:
# computing neighbors
#     finished (0:00:39) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:08) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# computing velocities
#     finished (0:00:20) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)

# %%
scv.tl.velocity_graph(adata)
# Out:
# computing velocity graph
#     finished (0:04:57) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
adata.obs
# Out:
#                            CC.Difference  Dev_IR_Diff  Dev_IR_Diff_zscore  \
# G885_L_AACTTTCGTTTACTCT        -0.094683    -0.027116            0.734460
# G885_L_ACGGGCTTCGCATGGC        -0.210323    -0.064220            0.324734
# G885_L_AAGGCAGCATAGTAAG         0.157365    -0.055505            0.420975
# G885_L_ACAGCCGCACGTCAGC        -0.087942    -0.047969            0.504191
# G885_L_ACATCAGTCCTGTAGA         0.322043    -0.009207            0.932221
# ...                                  ...          ...                 ...
# G945-I_L_TTTGTCAGTTCGCTAA      -0.151301    -0.236529           -1.578001
# G945-I_L_TTTGCGCCATGTCGAT       0.078827    -0.196677           -1.137933
# G945-I_L_TTTGTCAAGGATGTAT       0.445665    -0.150784           -0.631150
# G945-I_L_TTTGGTTGTTCGAATC       0.164393    -0.170197           -0.845519
# G945-I_L_TTTGGTTGTTTGGGCC      -0.067279    -0.174149           -0.889166
#
#                            G2M.Score  Neftel_AC_AUC  Neftel_G1.S_AUC  \
# G885_L_AACTTTCGTTTACTCT     0.346386       0.176188         0.209574
# G885_L_ACGGGCTTCGCATGGC     0.364562       0.179836         0.094346
# G885_L_AAGGCAGCATAGTAAG    -0.070514       0.192656         0.106126
# G885_L_ACAGCCGCACGTCAGC     0.112628       0.193978         0.064896
# G885_L_ACATCAGTCCTGTAGA    -0.070117       0.225541         0.115407
# ...                              ...            ...              ...
# G945-I_L_TTTGTCAGTTCGCTAA   0.138388       0.053953         0.055865
# G945-I_L_TTTGCGCCATGTCGAT  -0.016065       0.068915         0.089991
# G945-I_L_TTTGTCAAGGATGTAT   0.125419       0.031933         0.200828
# G945-I_L_TTTGGTTGTTCGAATC   0.055345       0.049248         0.140394
# G945-I_L_TTTGGTTGTTTGGGCC    0.392773   0.050348  G945-I_L_TTTGGTTGTTTGGGCC
#
#                            initial_size_spliced  initial_size_unspliced  \
# G885_L_AACTTTCGTTTACTCT                   17415                    5937
# G885_L_ACGGGCTTCGCATGGC                   19269                    5138
# G885_L_AAGGCAGCATAGTAAG                   17750                    3707
# G885_L_ACAGCCGCACGTCAGC                   15163                    4447
# G885_L_ACATCAGTCCTGTAGA                   11951                    4359
# ...                                         ...                     ...
# G945-I_L_TTTGTCAGTTCGCTAA                  2219                     809
# G945-I_L_TTTGCGCCATGTCGAT                 13526                    4034
# G945-I_L_TTTGTCAAGGATGTAT                  1909                     797
# G945-I_L_TTTGGTTGTTCGAATC                  1910                    1147
# G945-I_L_TTTGGTTGTTTGGGCC                  5971                     774
#
#                            initial_size     n_counts  velocity_self_transition
# G885_L_AACTTTCGTTTACTCT         17415.0  8846.517578                  0.098726
# G885_L_ACGGGCTTCGCATGGC         19269.0  8964.323242                  0.107614
# G885_L_AAGGCAGCATAGTAAG         17750.0  9242.324219                  0.013174
# G885_L_ACAGCCGCACGTCAGC         15163.0  9354.621094                  0.111849
# G885_L_ACATCAGTCCTGTAGA         11951.0  8928.096680                  0.199082
# ...                                 ...          ...                       ...
# G945-I_L_TTTGTCAGTTCGCTAA        2219.0  7779.730957                  0.101162
# G945-I_L_TTTGCGCCATGTCGAT       13526.0  8861.441406                  0.149816
# G945-I_L_TTTGTCAAGGATGTAT        1909.0  9324.339844                  0.126126
# G945-I_L_TTTGGTTGTTCGAATC        1910.0  8863.299805                  0.225944
# G945-I_L_TTTGGTTGTTTGGGCC        5971.0  9905.338867                  0.078467
#
# [79862 rows x 133 columns]

# %%
PCA_coords = adata.obs.loc[:, ['PC1', 'PC2']].to_numpy()

# %%
adata.obs.keys()
# Out:
# Index(['CC.Difference', 'Dev_IR_Diff', 'Dev_IR_Diff_zscore', 'G2M.Score',
#        'Neftel_AC_AUC', 'Neftel_G1.S_AUC', 'Neftel_G2.M_AUC',
#        'Neftel_MES1_AUC', 'Neftel_MES2_AUC', 'Neftel_NPC1_AUC',
#        ...
#        'orig.ident', 'percent.mito', 'scBTSC_AUC', 'scGBM_AUC', 'unique_id',
#        'initial_size_spliced', 'initial_size_unspliced', 'initial_size',
#        'n_counts', 'velocity_self_transition'],
#       dtype='object', length=133)

# %%
adata.obsm['DR'] = PCA_coords

# %%
scv.pl.velocity_embedding_stream(adata, basis = 'DR', color = 'Dev_IR_Diff_zscore', figsize = (10, 7),
                                color_map = cm.RdYlBu)
# Out:
# Renamed 'DR' to convention 'X_DR' (adata.obsm).
# computing velocity embedding
#     finished (0:00:22) --> added
#     'velocity_DR', embedded velocity vectors (adata.obsm)

# %%
scv.pl.velocity_embedding_stream(adata, basis = 'DR', color = 'Stem_Astro_Diff_zscore', figsize = (10, 7),
                                color_map = cm.RdYlBu)

# %%
scv.pl.velocity_embedding_stream(adata, basis = 'DR', color = 'orig.ident', figsize = (10, 7))
