# %% [markdown]
# ----
# # Plot Oligodendrocyte Gene Signatures in Tumor Cells
# ----
#
# We want to show which cell types are most similar to Tumour cells across patients
#
# /cluster/projects/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/MatureOligodendrocytes

# %%
library(pheatmap)
library(ggplot2)
library(gridExtra)
library(ggpubr)
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/MatureOligodendrocytes")

# %%
meta <- readRDS("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/AstrocyteScoring/GSC_Tumours/Astrocyte_AUCell_meta_GSC_T.rds")
colnames(meta) <- gsub("Population", "AstrocytePopulation", colnames(meta))
head(meta)
# Out:
#                               nGene nUMI  orig.ident percent.mito S.Score
# BTSC_BT127_L_AAACCTGCACGGACAA  640    875 BTSC       0.043428571   0.0957859
# BTSC_BT127_L_AAACCTGCATCCGGGT 1036   2408 BTSC       0.002076412   0.0535880
# BTSC_BT127_L_AAACCTGGTACAGTTC 3240  10058 BTSC       0.078047326   0.2119064
# BTSC_BT127_L_AAACCTGTCTACGAGT 3337  10798 BTSC       0.061863308  -0.1322671
# BTSC_BT127_L_AAACGGGAGTGGTAAT 4140  14601 BTSC       0.081501267   0.4082643
# BTSC_BT127_L_AAACGGGCAGGACGTA  543    820 BTSC       0.108536585  -0.1085568
#                               G2M.Score   Phase CC.Difference
# BTSC_BT127_L_AAACCTGCACGGACAA  0.07303696 S      0.022748941
# BTSC_BT127_L_AAACCTGCATCCGGGT  0.30872825 G2M   -0.255140251
# BTSC_BT127_L_AAACCTGGTACAGTTC -0.22082262 S      0.432729024
# BTSC_BT127_L_AAACCTGTCTACGAGT -0.20464285 G1     0.072375715
# BTSC_BT127_L_AAACGGGAGTGGTAAT  0.40187978 S      0.006384479
# BTSC_BT127_L_AAACGGGCAGGACGTA -0.14419756 G1     0.035640733
#                               Zhong_NPCs_upreg_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0.10663091
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.19311215
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.10956094
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.07132768
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.25821914
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.04803011
#                               Zhong_Excitatory_neurons_upreg_AUC ⋯
# BTSC_BT127_L_AAACCTGCACGGACAA 0.000000000                        ⋯
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.095520701                        ⋯
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.007489049                        ⋯
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.000000000                        ⋯
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.007630352                        ⋯
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.000000000                        ⋯
#                               Lin_NatNeurosci_2017_AstrocytePopulationD_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0.06105958
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.06406926
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.09777365
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.06800660
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.05124717
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.06792414
#                               Lin_NatNeurosci_2017_AstrocytePopulationE_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0.07507290
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.12230042
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.11890197
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.12129185
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.09712995
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.06715780
#                               Morel_JNeurosci_2017_CortexAstrocytes_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0.009066071
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.000000000
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.000000000
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.000000000
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.000000000
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.000000000
#                               Morel_JNeurosci_2017_HippocampusAstrocytes_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0.00000000
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.13607461
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.08760774
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.01031511
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.17069380
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.00000000
#                               Morel_JNeurosci_2017_NaccRegionAstrocytes_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0
# BTSC_BT127_L_AAACCTGCATCCGGGT 0
# BTSC_BT127_L_AAACCTGGTACAGTTC 0
# BTSC_BT127_L_AAACCTGTCTACGAGT 0
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0
# BTSC_BT127_L_AAACGGGCAGGACGTA 0
#                               Morel_JNeurosci_2017_CpuRegionAstrocytes_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0.00000000
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.05402877
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.00000000
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.01958835
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.04362063
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.00000000
#                               Morel_JNeurosci_2017_ThalamusAstrocytes_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0.00000000
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.00000000
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.00000000
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.00000000
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.00000000
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.07699901
#                               Morel_JNeurosci_2017_HypothalamusAstrocytes_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0
# BTSC_BT127_L_AAACCTGCATCCGGGT 0
# BTSC_BT127_L_AAACCTGGTACAGTTC 0
# BTSC_BT127_L_AAACCTGTCTACGAGT 0
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0
# BTSC_BT127_L_AAACGGGCAGGACGTA 0
#                               Chai_Neuron_2017_AdultHippocampalAstrocytes_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0.05691161
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.04203807
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.03354806
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.03333430
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.03858105
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.04619077
#                               Chai_Neuron_2017_AdultStriatumAstrocytes_AUC
# BTSC_BT127_L_AAACCTGCACGGACAA 0.06021974
# BTSC_BT127_L_AAACCTGCATCCGGGT 0.03468961
# BTSC_BT127_L_AAACCTGGTACAGTTC 0.05416663
# BTSC_BT127_L_AAACCTGTCTACGAGT 0.06407349
# BTSC_BT127_L_AAACGGGAGTGGTAAT 0.05392528
# BTSC_BT127_L_AAACGGGCAGGACGTA 0.07626926

# %%
### subset to only tumour cells
tumour <- meta[meta$orig.ident == "GBM", ]
colnames(tumour) <- gsub("Population", "AstrocytePopulation", colnames(tumour))
tumour <- tumour[ ,grep("_AUC", colnames(tumour))]
colnames(tumour) <- gsub("_AUC", "", colnames(tumour))
dim(tumour)

### save data
saveRDS(tumour, file = "TumourCells_AUCell_GeneSignatures.rds")
# Out:
# [1] 14207   241

# %%
subset <- c(colnames(tumour)[grep("dendro", colnames(tumour))],
            colnames(tumour)[grep("OPC", colnames(tumour))],
            colnames(tumour)[grep("OL", colnames(tumour))],
            colnames(tumour)[grep("OL", colnames(tumour))],
            colnames(tumour)[grep("MOG", colnames(tumour))]
           )
subset <- tumour[ , subset]
dim(subset)
# Out:
# [1] 14207    16

# %%
### split barcodes for PatientID
### plot 2x8 grid of signatures as violing plots / sample
x <- strsplit(rownames(subset), "_")
patient <- sapply( x, "[", 2 )
patient <- strsplit(patient, "-")
patient <- sapply(patient, "[", 1 )

subset$sample <- paste0(patient, "_T")

# %%
i <- 8

p <- 
p
# Out:
# plot without title

# %%
p_list <- list()

for (i in 1:(ncol(subset) - 1)){
    
    sig <- colnames(subset)[i]
    
    p_list[[i]] <- ggplot(subset, aes_string(x="sample", y=sig)) + 
  geom_violin() + geom_boxplot(width=0.1, outlier.shape = NA) + 
  ylab("AUCell Score") + theme_classic() + ggtitle(sig) + xlab("")
    
}

# %%
# Out:
# [[1]]
# plot without title
