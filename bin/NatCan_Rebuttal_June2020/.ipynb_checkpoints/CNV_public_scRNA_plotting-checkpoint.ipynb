# %% [markdown]
# ----
# # CNV inference in public scRNA GBM datasets
# ---
# /cluster/projects/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/plotting

# %%
#options(repos='http://cran.rstudio.com/')
#library(devtools)
#install_github("jokergoo/ComplexHeatmap")
library(ComplexHeatmap)
library(data.table)
library(pheatmap)
library(RColorBrewer)
library(grid)
library(ggplot2)
library(ggExtra)
library(ggpubr)
library(dplyr)

# %% [markdown]
# ---
# ## 1.0 Plot copy number heatmap
# ---
#
#
# ### 1.1 Darmanis et al.

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Darmanis/Cutoff_1/")

# %%
cnvs <- readRDS("Darmanis_Ordered_CNV_matrix.rds")
cnv.genes <- readRDS("Darmanis_CNVgenes.rds")
meta <- readRDS("../Darmanis_TumourOnly_meta.rds")

# %%
### make row annotations (sample)
annotat.row <- data.frame(colnames(cnvs))
colnames(annotat.row) <- "Cell"
rownames(annotat.row) <- annotat.row$Cell
annotat.row$Cell <- gsub("VIZ.X", "", annotat.row$Cell)
annotat.row$Sample <- NA
annotat.row <- annotat.row[paste0("VIZ.X", meta$SampleName), ]
annotat.row$Sample <- meta$PatientID
annotat.row$Cell <- NULL
dim(annotat.row)
head(annotat.row)

##subset cnvs
cnvs <- cnvs[ ,rownames(annotat.row)]
dim(cnvs)
# Out:
# [1] 1091    1
#                     Sample
# VIZ.X1001000173.G8  BT_S2
# VIZ.X1001000173.B4  BT_S2
# VIZ.X1001000173.A2  BT_S2
# VIZ.X1001000173.E2  BT_S2
# VIZ.X1001000173.F6  BT_S2
# VIZ.X1001000173.B12 BT_S2
# [1] 9907 1091

# %%
mat_colors <- list(Chromosome = c(rep(c("lightgrey", "darkgrey"), 11)),
                       Sample = brewer.pal(length(unique(annotat.row$Sample)), "Set3")
                   )

names(mat_colors$Chromosome) <- unique(cnv.genes$Chromosome)
names(mat_colors$Sample) <- unique(annotat.row$Sample)
mat_colors

cols <- c("#67001f",
          "#b2182b",
          "#d6604d",
          "#f4a582",
          "#fddbc7",
          #"#fddbc7",
          "white",
          "white",
          "white",
          "#92c5de",
          "#4393c3",
          "#2166ac",
          "#053061",
          "#053061"
          )
colfunc <- colorRampPalette(cols)
cnv.cols <- colfunc(50)
# Out:
# $Chromosome
#           1           2           3           4           5           6
# "lightgrey"  "darkgrey" "lightgrey"  "darkgrey" "lightgrey"  "darkgrey"
#           7           8           9          10          11          12
# "lightgrey"  "darkgrey" "lightgrey"  "darkgrey" "lightgrey"  "darkgrey"
#          13          14          15          16          17          18
# "lightgrey"  "darkgrey" "lightgrey"  "darkgrey" "lightgrey"  "darkgrey"
#          19          20          21          22
# "lightgrey"  "darkgrey" "lightgrey"  "darkgrey"
#
# $Sample
#     BT_S2     BT_S1     BT_S4     BT_S6
# "#8DD3C7" "#FFFFB3" "#BEBADA" "#FB8072"

# %%
pheatmap(t(cnvs),
         color = rev(cnv.cols),
         cluster_rows = FALSE,
         cluster_cols = FALSE,
         show_colnames = FALSE,
         show_rownames = FALSE,
         annotation_col = cnv.genes,
         annotation_row = annotat.row,
         annotation_colors = mat_colors,
         fontsize_row = 9,
         border_color = "black",
         annotation_legend = TRUE,
         legend = TRUE,
         height = 8,
         width = 15,
         filename = "Darmanis_TumourCNVs.jpeg"
        )

# %%
pheatmap(t(cnvs),
         color = rev(cnv.cols),
         cluster_rows = TRUE,
         cluster_cols = FALSE,
         show_colnames = FALSE,
         show_rownames = FALSE,
         treeheight_row = 10,
         annotation_col = cnv.genes,
         annotation_row = annotat.row,
         annotation_colors = mat_colors,
         fontsize_row = 9,
         border_color = "black",
         annotation_legend = TRUE,
         legend = TRUE,
         height = 8,
         width = 17,
         filename = "Darmanis_TumourCNVs_Clustered.jpeg"
        )

# %% [markdown]
# ### 1.2 Neftel et al.,

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Neftel/Cutoff_1/")

# %%
cnvs <- readRDS("Neftel_Ordered_CNV_matrix.rds")
cnv.genes <- readRDS("Neftel_CNVgenes.rds")
meta <- readRDS("../Neftel_TumourOnly_meta.rds")

# %%
### make row annotations (sample)
annotat.row <- data.frame(colnames(cnvs))
colnames(annotat.row) <- "Cell"
rownames(annotat.row) <- annotat.row$Cell
annotat.row$Cell <- gsub("VIZ.X", "", annotat.row$Cell)
annotat.row$Sample <- NA
annotat.row <- annotat.row[annotat.row$Cell %in% rownames(meta), ]
annotat.row$Sample <- meta$Sample
annotat.row$Cell <- NULL
head(annotat.row)
dim(annotat.row)

##subset cnvs
cnvs <- cnvs[ ,rownames(annotat.row)]
dim(cnvs)
# Out:
#        Sample
# VIZ.X2 MGH100
# VIZ.X3 MGH100
# VIZ.X4 MGH100
# VIZ.X5 MGH100
# VIZ.X6 MGH100
# VIZ.X7 MGH100
# [1] 4916    1
# [1] 2554 4916

# %%
mat_colors <- list(Chromosome = c(rep(c("lightgrey", "darkgrey"), 11)),
                       Sample = c(brewer.pal(12, "Set3"), brewer.pal(8, "Set2"))
                   )

names(mat_colors$Chromosome) <- unique(cnv.genes$Chromosome)
names(mat_colors$Sample) <- unique(annotat.row$Sample)
mat_colors

cols <- c("#67001f",
          "#b2182b",
          "#d6604d",
          "#f4a582",
          "#fddbc7",
          "#fddbc7",
          #"white",
          "white",
          #"white",
          "#92c5de",
          "#4393c3",
          "#2166ac",
          "#053061",
          "#053061"
          )
colfunc <- colorRampPalette(cols)
cnv.cols <- colfunc(50)
# Out:
# $Chromosome
#           1           2           3           4           5           6
# "lightgrey"  "darkgrey" "lightgrey"  "darkgrey" "lightgrey"  "darkgrey"
#           7           8           9          10          11          12
# "lightgrey"  "darkgrey" "lightgrey"  "darkgrey" "lightgrey"  "darkgrey"
#          13          14          15          16          17          18
# "lightgrey"  "darkgrey" "lightgrey"  "darkgrey" "lightgrey"  "darkgrey"
#          19          20          21          22
# "lightgrey"  "darkgrey" "lightgrey"  "darkgrey"
#
# $Sample
#    MGH100    MGH101    MGH102    MGH104    MGH105    MGH106    MGH110    MGH113
# "#8DD3C7" "#FFFFB3" "#BEBADA" "#FB8072" "#80B1D3" "#FDB462" "#B3DE69" "#FCCDE5"
#    MGH115    MGH121    MGH122    MGH124    MGH125    MGH128    MGH129    MGH136
# "#D9D9D9" "#BC80BD" "#CCEBC5" "#FFED6F" "#66C2A5" "#FC8D62" "#8DA0CB" "#E78AC3"
#    MGH143    MGH151    MGH152     MGH66
# "#A6D854" "#FFD92F" "#E5C494" "#B3B3B3"

# %%
pheatmap(t(cnvs),
         color = rev(cnv.cols),
         cluster_rows = TRUE,
         cluster_cols = FALSE,
         show_colnames = FALSE,
         show_rownames = FALSE,
         treeheight_row = 10,
         annotation_col = cnv.genes,
         annotation_row = annotat.row,
         annotation_colors = mat_colors,
         fontsize_row = 9,
         border_color = "black",
         annotation_legend = TRUE,
         legend = TRUE,
         height = 8,
         width = 17,
         filename = "Neftel_TumourCNVs_Clustered.jpeg"
        )

# %%
pheatmap(t(cnvs),
         color = rev(cnv.cols),
         cluster_rows = TRUE,
         cluster_cols = FALSE,
         show_colnames = FALSE,
         show_rownames = FALSE,
         treeheight_row = 10,
         annotation_col = cnv.genes,
         annotation_row = annotat.row,
         annotation_colors = mat_colors,
         fontsize_row = 9,
         border_color = "black",
         annotation_legend = TRUE,
         legend = TRUE,
         height = 12,
         width = 17,
         filename = "Neftel_TumourCNVs_Clustered_higher.jpeg"
        )

# %% [markdown]
# ---
# ## 2.0 Plot Developmental-Injury Response Gradient
# ---

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/")

# %%
darmanis <- readRDS("./Darmanis/Darmanis_AUCell_Scores.rds")
neftel <- readRDS("./Neftel/Neftel_AUCell_Scores.rds")
combo.dat <- readRDS("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/Nuclei_rescore/GSC_GBM_NuclieLive_Meta.rds")

# %%
str(darmanis$Developmental_GSC_AUC)
# Out:
#  num [1:1091] 0.1058 0.0863 0.1884 0.1688 0.207 ...

# %%
d <- ggscatterhist(darmanis, 
              x = "Developmental_GSC_AUC", 
              y = "InjuryResponse_GSC_AUC",
              #palette = brewer.pal(length(unique(darmanis$PatientID)), "Dark2"), 
              color = brewer.pal(length(unique(darmanis$PatientID)), "Dark2")[2],
              size = 0.5,
              alpha = 0.5,
              xlab = "Developmental Score (AUC)",
              ylab = "Injury Response Score (AUC)",
              #ellipse = TRUE, 
              #ellipse.type = "confidence",
              margin.params = list(fill = brewer.pal(length(unique(darmanis$PatientID)), "Dark2")[2], color = "black", size = 0.2),
              ggtheme = theme_classic(),
              #ellipse.alpha = 0
            ylim = c(0.1,0.45),
              xlim = c(0,0.35),
             print = F
             )  

d$sp <- d$sp +
geom_hline(yintercept = 0.2, linetype = "dashed", lwd = 1, color = "darkgrey") +
geom_vline(xintercept = 0.11, linetype = "dashed", lwd = 1, color = "darkgrey") 
d
# Out:
# plot without title

# %%
n <- ggscatterhist(neftel, 
              x = "Developmental_GSC_AUC", 
              y = "InjuryResponse_GSC_AUC",
              #palette = brewer.pal(length(unique(darmanis$PatientID)), "Dark2"), 
              color = brewer.pal(length(unique(darmanis$PatientID)), "Dark2")[1],
              size = 0.5,
              alpha = 0.5,
              xlab = "Developmental Score (AUC)",
              ylab = "Injury Response Score (AUC)",
              #ellipse = TRUE, 
              #ellipse.type = "confidence",
              margin.params = list(fill = brewer.pal(length(unique(darmanis$PatientID)), "Dark2")[1], color = "black", size = 0.2),
              ggtheme = theme_classic(),
              #ellipse.alpha = 0
          ylim = c(0.1,0.45),
              xlim = c(0,0.35),
              print = F
             )  

n$sp <- n$sp +
geom_hline(yintercept = 0.2, linetype = "dashed", lwd = 1, color = "darkgrey") +
geom_vline(xintercept = 0.11, linetype = "dashed", lwd = 1, color = "darkgrey") 
n
# Out:
# plot without title

# %%
cells <- combo.dat[combo.dat$Technology == "LiveCell", ]
og <- ggscatterhist(cells, 
              x = "Developmental_AUC", 
              y = "InjuryResponse_AUC",
              palette = c("#225ea8", "black", "red"), 
              color = "SampleType",
              size = 0.5,
              alpha = 0.5,
              xlab = "Developmental Score (AUC)",
              ylab = "Injury Response Score (AUC)",
              #ellipse = TRUE, 
              #ellipse.type = "confidence",
              margin.params = list(fill = "SampleType", color = "black", size = 0.2),
              ggtheme = theme_classic(),
              #ellipse.alpha = 0
              ylim = c(0.1,0.45),
              xlim = c(0,0.35),
              print = F,
              legend = "none"
             )  

og$sp <- og$sp +
geom_hline(yintercept = 0.2, linetype = "dashed", lwd = 1, color = "darkgrey") +
geom_vline(xintercept = 0.11, linetype = "dashed", lwd = 1, color = "darkgrey") 
og
# Out:
# plot without title

# %%
pdf("Public_scRNA_Gradient.pdf", width = 5, height = 5)
d
n
og
dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# ---
# ## 3.0 Define gain/loss cutoffs
# ---
#
# https://stackoverflow.com/questions/25264461/find-local-minimum-in-bimodal-distribution-with-r
#
# Neftel: Gain > 0.133, Deletion < -0.109
# Darmanis: Gain > 0.175, Deletion < -0.197

# %% [markdown]
# ### 3.1 Darmanis

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Darmanis/Cutoff_1/")
cnvs <- readRDS("Darmanis_Ordered_CNV_matrix.rds")
cnv.genes <- readRDS("Darmanis_CNVgenes.rds")

### average inferCNV scores across chromosomes
chr7 <- colMeans(cnvs[rownames(cnv.genes)[cnv.genes$Chromosome == 7], ])
chr10 <- colMeans(cnvs[rownames(cnv.genes)[cnv.genes$Chromosome == 10], ])

pdf("Darmanis_Chr_Cutoffs.pdf", width = 10, height = 4)
par(mfrow=c(1,2))
### plot inferCNV scores on chromosome 7 to define amplification
d <- density(chr7)
hist(chr7, prob=TRUE, ylim=c(0,3), breaks = 50, col = "grey", 
     main = "Average Chromosome 7 Signal\n(Darmanis et al.)",
     xlab = "InferCNV Score"
    )
lines(d, col="red", lty=2, lwd = 2)
v <- optimize(approxfun(d$x,d$y), interval =c(min(chr7),max(chr7)))$minimum
abline(v=v, col="blue", lwd = 3)
v

### plot inferCNV scores on chromosome 10 to define loss threshold
d <- density(chr10)
hist(chr10, prob=TRUE, ylim=c(0,3), breaks = 50, col = "grey", 
     main = "Average Chromosome 10 Signal\n(Darmanis et al.)",
     xlab = "InferCNV Score"
    )
lines(d, col="red", lty=2, lwd = 2)
v <- optimize(approxfun(d$x,d$y), interval =c(-0.6,max(chr10)))$minimum
abline(v=v, col="blue", lwd = 3)
v

dev.off()
# Out:
# [1] 0.1752447
# [1] -0.1966744
# pdf
#   2

# %% [markdown]
# ### 3.2 Neftel

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Neftel/Cutoff_1/")
cnvs <- readRDS("Neftel_Ordered_CNV_matrix.rds")
cnv.genes <- readRDS("Neftel_CNVgenes.rds")

### average inferCNV scores across chromosomes
chr7 <- colMeans(cnvs[rownames(cnv.genes)[cnv.genes$Chromosome == 7], ])
chr10 <- colMeans(cnvs[rownames(cnv.genes)[cnv.genes$Chromosome == 10], ])

pdf("Neftel_Chr_Cutoffs.pdf", width = 10, height = 4)
par(mfrow=c(1,2))
### plot inferCNV scores on chromosome 7 to define amplification
d <- density(chr7)
hist(chr7, prob=TRUE, ylim=c(0,4), breaks = 100, col = "grey", 
     main = "Average Chromosome 7 Signal\n(Neftel et al.)",
     xlab = "InferCNV Score"
    )
lines(d, col="red", lty=2, lwd = 2)
v <- optimize(approxfun(d$x,d$y), interval =c(-0.1,0.55))$minimum
abline(v=v, col="blue", lwd = 3)
v

### plot inferCNV scores on chromosome 10 to define loss threshold
d <- density(chr10)
hist(chr10, prob=TRUE, ylim=c(0,6), breaks = 100, col = "grey", 
     main = "Average Chromosome 10 Signal\n(Neftel et al.)",
     xlab = "InferCNV Score"
    )
lines(d, col="red", lty=2, lwd = 2)
v <- optimize(approxfun(d$x,d$y), interval =c(-0.5,0.4))$minimum
abline(v=v, col="blue", lwd = 3)
v

dev.off()
# Out:
# [1] 0.1327258
# [1] -0.1086938
# pdf
#   2

# %% [markdown]
# ---
# ## 4.0 Match genes to chromosome arms and average
# ---

# %%
### download gene - chr arm position file 
chrarms <- read.table("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_TCGA/data/chr_arms.txt", header = T)
#head(chrarms)

# %% [markdown]
# ### 4.1 Darmanis

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Darmanis/Cutoff_1/")

# %%
cnv.genes <- readRDS("Darmanis_CNVgenes.rds")

### load start and end positions for all genes
gene.pos <- read.table("~/Desktop/H4H/pughlab/projects/OICR_Brain_NucSeq/GBM/analysis/inferCNV/input/GRCh38-1.2.0_premrna_genomicPositions.txt")
colnames(gene.pos) <- c("Gene", "Chromosome", "Start", "End")
rownames(gene.pos) <- gene.pos$Gene
#head(gene.pos)

### subset to only genes in datasets CNVs
gene.pos <- gene.pos[rownames(cnv.genes), ]
#head(gene.pos)

### match genes to chromsome arm
gene.arm <- c()

for (i in 1:nrow(gene.pos)){

     arm.subset <- chrarms[chrarms$Chrom == gene.pos$Chromosome[i] ,]
     gene.arm[i] <- ifelse(gene.pos$End[i] > arm.subset[1 ,"End"],
           as.character(arm.subset$Idf[2]), #greater than p arm end = q
           as.character(arm.subset$Idf[1]) #NOT greater than p arm end = p
         )
}
gene.pos$arm <- gene.arm
#head(gene.pos)

## save data 
saveRDS(gene.pos, file = "Darmanis_CNVgenes_arm.rds")

# %%
### average cnv signal across chromsome arm
cnvs <- readRDS("Darmanis_Ordered_CNV_matrix.rds")
colnames(cnvs) <- gsub("VIZ." , "", colnames(cnvs))
meta <- readRDS("../Darmanis_TumourOnly_meta.rds")


### add avgs to meta
arm_avg <- list() #average scores across arm
arms <- unique(gene.pos$arm)

for (i in 1:length(arms)){
    #print(arms[i])
    genes <- as.character(gene.pos[gene.pos$arm == arms[i], ]$Gene)
    name <- paste0("chr", arms[i], "_Avg")
    cnv.subset <- cnvs[genes, ] #subset cnv data to chr arm
    arm_avg[[name]] <- colMeans(cnv.subset) #mean
    
}

arm_avg <- do.call(rbind, arm_avg)
arm_avg <- t(arm_avg)
arm_avg <- arm_avg[rownames(meta), ]
dim(arm_avg)
meta <- cbind(meta, arm_avg)
#head(meta)

### classify arms as gain or deletion
gain_cutoff <- 0.175
del_cutoff <- -0.197

arm_avg[arm_avg > gain_cutoff] <- 1
arm_avg[arm_avg <= del_cutoff] <- -1
arm_avg[between(arm_avg, del_cutoff, gain_cutoff)] <- 0
colnames(arm_avg) <- gsub("_Avg", "_Class", colnames(arm_avg))
meta <- cbind(meta, arm_avg)
head(meta)

saveRDS(meta, "Darmanis_meta_avgchrarms.rds")
# Out:
# [1] 1091   38
#                 SampleName     Title      SourceName Organism     PlateID
# X1001000173.G8  1001000173.G8  GBM cell 1 Brain      Homo sapiens 1001000173
# X1001000173.B4  1001000173.B4  GBM cell 3 Brain      Homo sapiens 1001000173
# X1001000173.A2  1001000173.A2  GBM cell 4 Brain      Homo sapiens 1001000173
# X1001000173.E2  1001000173.E2  GBM cell 5 Brain      Homo sapiens 1001000173
# X1001000173.F6  1001000173.F6  GBM cell 6 Brain      Homo sapiens 1001000173
# X1001000173.B12 1001000173.B12 GBM cell 7 Brain      Homo sapiens 1001000173
#                 Well Tissue PatientID tSNEcluster CellType   ⋯ chr16q_Class
# X1001000173.G8  G8   Tumor  BT_S2     11          Neoplastic ⋯ 0
# X1001000173.B4  B4   Tumor  BT_S2     11          Neoplastic ⋯ 0
# X1001000173.A2  A2   Tumor  BT_S2     11          Neoplastic ⋯ 0
# X1001000173.E2  E2   Tumor  BT_S2     11          Neoplastic ⋯ 0
# X1001000173.F6  F6   Tumor  BT_S2     11          Neoplastic ⋯ 0
# X1001000173.B12 B12  Tumor  BT_S2     11          Neoplastic ⋯ 0
#                 chr17p_Class chr17q_Class chr18q_Class chr19p_Class
# X1001000173.G8   0           -1           0            1
# X1001000173.B4  -1           -1           0            1
# X1001000173.A2   0            0           0            0
# X1001000173.E2   0            0           0            0
# X1001000173.F6   0            0           0            1
# X1001000173.B12 -1           -1           0            0
#                 chr19q_Class chr20p_Class chr20q_Class chr21q_Class
# X1001000173.G8  0            0            0            -1
# X1001000173.B4  0            1            1             0
# X1001000173.A2  0            0            0             0
# X1001000173.E2  0            0            0            -1
# X1001000173.F6  0            0            0             0
# X1001000173.B12 0            0            0             0
#                 chr22q_Class
# X1001000173.G8   0
# X1001000173.B4  -1
# X1001000173.A2  -1
# X1001000173.E2  -1
# X1001000173.F6  -1
# X1001000173.B12 -1

# %% [markdown]
# ### 4.2 Neftel

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Neftel/Cutoff_1/")

# %%
cnv.genes <- readRDS("Neftel_CNVgenes.rds")

### load start and end positions for all genes
gene.pos <- read.table("~/Desktop/H4H/pughlab/projects/OICR_Brain_NucSeq/GBM/analysis/inferCNV/input/GRCh38-1.2.0_premrna_genomicPositions.txt")
colnames(gene.pos) <- c("Gene", "Chromosome", "Start", "End")
rownames(gene.pos) <- gene.pos$Gene
#head(gene.pos)

### subset to only genes in datasets CNVs
gene.pos <- gene.pos[rownames(cnv.genes), ]
#head(gene.pos)

### match genes to chromsome arm
gene.arm <- c()

for (i in 1:nrow(gene.pos)){

     arm.subset <- chrarms[chrarms$Chrom == gene.pos$Chromosome[i] ,]
     gene.arm[i] <- ifelse(gene.pos$End[i] > arm.subset[1 ,"End"],
           as.character(arm.subset$Idf[2]), #greater than p arm end = q
           as.character(arm.subset$Idf[1]) #NOT greater than p arm end = p
         )
}
gene.pos$arm <- gene.arm
#head(gene.pos)

## save data 
saveRDS(gene.pos, file = "Neftel_CNVgenes_arm.rds")

# %%
### average cnv signal across chromsome arm
cnvs <- readRDS("Neftel_Ordered_CNV_matrix.rds")
colnames(cnvs) <- gsub("VIZ." , "", colnames(cnvs))
meta <- readRDS("../Neftel_TumourOnly_meta.rds")

# %%
### add avgs to meta
arm_avg <- list() #average scores across arm
arms <- unique(gene.pos$arm)

for (i in 1:length(arms)){
    #print(arms[i])
    genes <- as.character(gene.pos[gene.pos$arm == arms[i], ]$Gene)
    name <- paste0("chr", arms[i], "_Avg")
    cnv.subset <- cnvs[genes, ] #subset cnv data to chr arm
    arm_avg[[name]] <- colMeans(cnv.subset) #mean
    
}

arm_avg <- do.call(rbind, arm_avg)
arm_avg <- t(arm_avg)

arm_avg <- arm_avg[paste0("X", rownames(meta)), ]
dim(arm_avg)

meta <- cbind(meta, arm_avg)
#head(meta)

### classify arms as gain or deletion
gain_cutoff <- 0.133
del_cutoff <- -0.109

arm_avg[arm_avg > gain_cutoff] <- 1
arm_avg[arm_avg <= del_cutoff] <- -1
arm_avg[between(arm_avg, del_cutoff, gain_cutoff)] <- 0
colnames(arm_avg) <- gsub("_Avg", "_Class", colnames(arm_avg))
meta <- cbind(meta, arm_avg)
head(meta)

saveRDS(meta, "Neftel_meta_avgchrarms.rds")
# Out:
# [1] 4916   33
#   NAME          Sample GBMType CellAssignment CrossSection GenesExpressed
# 2 MGH100-P5-A01 MGH100 Adult   Malignant      none         7403
# 3 MGH100-P5-A03 MGH100 Adult   Malignant      none         8861
# 4 MGH100-P5-A04 MGH100 Adult   Malignant      none         5957
# 5 MGH100-P5-A06 MGH100 Adult   Malignant      none         7320
# 6 MGH100-P5-A07 MGH100 Adult   Malignant      none         6513
# 7 MGH100-P5-A08 MGH100 Adult   Malignant      none         7886
#   GeneticSubclone MESlike2           MESlike1            AClike             ⋯
# 2 MGH100_3        -0.235210691098538 0.292177011540687   2.23440649321884   ⋯
# 3 NA              -0.646138155879352 -1.2536486798915    -0.64760798179912  ⋯
# 4 NA              2.25733451152936   -0.0739986658631031 -1.14362729808451  ⋯
# 5 MGH100_1        -0.557506241077064 -0.548720861252219  -0.799967504037717 ⋯
# 6 MGH100_3        0.506108672250265  0.299333647510028   -0.384538268905799 ⋯
# 7 MGH100_1        -0.821548787425602 -0.669993148649621  -0.727191606974573 ⋯
#   chr16p_Class chr16q_Class chr17p_Class chr17q_Class chr18q_Class chr19p_Class
# 2 0            0            0            0             0           0
# 3 0            0            1            1             0           0
# 4 0            0            0            0             0           0
# 5 0            0            0            0             0           0
# 6 0            0            0            0             0           0
# 7 1            1            1            0            -1           0
#   chr19q_Class chr20q_Class chr21q_Class chr22q_Class
# 2 0            0             0           0
# 3 0            0            -1           0
# 4 0            0            -1           0
# 5 0            0             0           0
# 6 0            0             0           0
# 7 0            0            -1           0

# %% [markdown]
# ### Combine Darmanis and Neftel CNV data

# %%
darmanis <- readRDS("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Darmanis/Cutoff_1/Darmanis_meta_avgchrarms.rds")
d_auc <- readRDS("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Darmanis/Darmanis_AUCell_Scores.rds")

neftel <- readRDS("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Neftel/Cutoff_1/Neftel_meta_avgchrarms.rds")
n_auc <- readRDS("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/Neftel/Neftel_AUCell_Scores.rds")

# %%
d_auc <- d_auc[ ,c("Developmental_GSC_AUC", "InjuryResponse_GSC_AUC")]
n_auc <- n_auc[ ,c("Developmental_GSC_AUC", "InjuryResponse_GSC_AUC")]

# %%
colnames(darmanis)[1] <- "Cell"
keep <- c("Cell", "PatientID", colnames(darmanis)[grep("^chr", colnames(darmanis))], colnames(darmanis)[grep("AUC", colnames(darmanis))])
darmanis <- darmanis[ ,keep]
darmanis$Study <- "Darmanis"
darmanis <- cbind(darmanis, d_auc)
#head(darmanis)

colnames(neftel)[1] <- "Cell"
colnames(neftel)[2] <- "PatientID"
keep <- c("Cell", "PatientID", colnames(neftel)[grep("^chr", colnames(neftel))], colnames(neftel)[grep("AUC", colnames(neftel))])
neftel <- neftel[ ,keep]
neftel$Study <- "Neftel"
neftel <- cbind(neftel, n_auc)
#head(neftel)

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/EnrichmentAnalysis/")
saveRDS(darmanis, file = "Darmanis_ChrArm_plotting.rds")
saveRDS(neftel, file = "Neftel_ChrArm_plotting.rds")

# %% [markdown]
# ---
# ## 5.0 Compare Dev/IR scores across
# ---

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/EnrichmentAnalysis/")

# %%
#dat <- readRDS("Darmanis_ChrArm_plotting.rds")
dat <- readRDS("Neftel_ChrArm_plotting.rds")

# %%
#### chr6q deletion vs others
chr <- "chr6q"
study <- "Neftel"
COI <- paste0(chr, "_Class")
event <- -1
sig <- "Developmental"

plot.dat_sub <- dat[ ,c(paste0(sig, "_GSC_AUC"), COI)]
plot.dat_sub[ ,COI] <- ifelse(plot.dat_sub[ ,COI] == event, 
                       print(event),
                       print("Other")
                      )
# Out:
# [1] -1
# [1] "Other"

# %%
file.name <- paste0(study, "_", chr, "_", event, "_", sig, ".pdf")

pdf(file.name, height = 5, width = 5)

ggboxplot(plot.dat_sub, 
          x = COI, 
          y = paste0(sig, "_GSC_AUC"),
          color = COI, 
          palette = c("black", "red"),
          add = "jitter",
          alpha = 0.8,
          xlab = "CNV State",
          ylab = paste0(sig, " GSVA Score"),
          main = paste0(sig, " - " , COI),
          legend = "none",
          #ylim = c(-1,1)
         )  + stat_compare_means(label.y = 0.8, label.x = 1.4) 

dev.off()
# Out:
# pdf
#   2

# %% [markdown]
# ----
# ## 6.0 Correlate CNV signal and program scores
# ----

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/CNV_public_scRNA/EnrichmentAnalysis/")

# %%
dat <- readRDS("Darmanis_ChrArm_plotting.rds")
head(dat)
# Out:
#                 Cell           PatientID chr1p_Avg  chr1q_Avg    chr2p_Avg
# X1001000173.G8  1001000173.G8  BT_S2     0.09103013  0.114454335 -0.26119262
# X1001000173.B4  1001000173.B4  BT_S2     0.16738742  0.141373995  0.11433129
# X1001000173.A2  1001000173.A2  BT_S2     0.14902494 -0.035561596 -0.01503796
# X1001000173.E2  1001000173.E2  BT_S2     0.12290668 -0.003388768 -0.05094343
# X1001000173.F6  1001000173.F6  BT_S2     0.03838048 -0.119053732 -0.11718309
# X1001000173.B12 1001000173.B12 BT_S2     0.10812438  0.078371197  0.11049388
#                 chr2q_Avg    chr3p_Avg    chr3q_Avg   chr4p_Avg   chr4q_Avg   ⋯
# X1001000173.G8  -0.253835082  0.002521219 -0.01718556 -0.03677571  0.07179124 ⋯
# X1001000173.B4  -0.101125955 -0.068811086  0.02082474  0.02836354  0.01743987 ⋯
# X1001000173.A2  -0.007439299  0.119181121  0.34980480 -0.02572259 -0.03388995 ⋯
# X1001000173.E2  -0.060354693  0.057948364  0.13055507 -0.12184722 -0.04499435 ⋯
# X1001000173.F6  -0.009456256  0.319741345  0.07904720 -0.23332623 -0.03511918 ⋯
# X1001000173.B12  0.049171969  0.035674289  0.07774218 -0.31316495 -0.46795687 ⋯
#                 chr18q_Class chr19p_Class chr19q_Class chr20p_Class
# X1001000173.G8  0            1            0            0
# X1001000173.B4  0            1            0            1
# X1001000173.A2  0            0            0            0
# X1001000173.E2  0            0            0            0
# X1001000173.F6  0            1            0            0
# X1001000173.B12 0            0            0            0
#                 chr20q_Class chr21q_Class chr22q_Class Study
# X1001000173.G8  0            -1            0           Darmanis
# X1001000173.B4  1             0           -1           Darmanis
# X1001000173.A2  0             0           -1           Darmanis
# X1001000173.E2  0            -1           -1           Darmanis
# X1001000173.F6  0             0           -1           Darmanis
# X1001000173.B12 0             0           -1           Darmanis
#                 Developmental_GSC_AUC InjuryResponse_GSC_AUC
# X1001000173.G8  0.10576889            0.2454929
# X1001000173.B4  0.08631514            0.2966884
# X1001000173.A2  0.18836495            0.1926231
# X1001000173.E2  0.16876472            0.1960785
# X1001000173.F6  0.20697939            0.1789991
# X1001000173.B12 0.07310575            0.3135832

# %%
chr <- "chr19p"
sig <- "InjuryResponse"

# %%
ggscatter(dat, 
          x = paste0(chr, "_Avg"),
          y = paste0(sig, "_GSC_AUC"),
          shape = 21,
          add = "reg.line", 
          add.params = list(color = "blue", fill = "lightgray"), # Customize reg. line
           conf.int = TRUE, # Add confidence interval
           cor.coef = TRUE, # Add correlation coefficient. see ?stat_cor
           cor.coeff.args = list(method = "pearson", label.sep = "\n")
         )
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title
