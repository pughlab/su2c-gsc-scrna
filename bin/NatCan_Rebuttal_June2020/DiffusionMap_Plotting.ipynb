# %% [markdown]
# ---
# # Plot Diffusion Map Results
# ---
#
# /cluster/projects/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/DiffusionMap/downsample/GSCs

# %%
install.packages("scatterplot3d") # Install
library("scatterplot3d") # load
library(ggplot2)
# Out:
# Installing package into ‘/Users/laura/Library/R/3.6/library’
# (as ‘lib’ is unspecified)
# The downloaded binary packages are in
# 	/var/folders/2w/pzy5vdps1x9d4gkf8tk8rh680000gp/T//RtmpM2Xpy6/downloaded_packages

# %% [markdown]
# ---
# ## 1.0 GSCs only (same genes as PCA)
# ---

# %%
setwd("~/Desktop/H4H/pughlab/projects/BTSCs_scRNAseq/Manuscript_G607removed/NatCan_Rebuttal/DiffusionMap/downsample/GSCs")

# %%
meta <- readRDS("GSC_500cells_allGenes_14000cells_DM_Metadata.rds")

# %%
plot(meta$DM1, meta$DM2)
# Out:
# plot without title

# %%
scatterplot3d(meta[,c("DM1", "DM2", "DM3")],
              grid = T,
              box = F
             )
# Out:
# plot without title

# %%
p <- ggplot(meta, aes(x = DM3, y = DM1)) + geom_point(aes(color=Diff)) +
     scale_color_gradientn(colors = c("red", "white", "blue"))

p
# Out:
# plot without title

# %%
meta$Diff <- meta$RNA.GSC.c1_AUC - meta$RNA.GSC.c2_AUC
